# %% [markdown]
# # AfterWork Data Science: Basics of Deep Learning and Neural Networks

# %% [markdown]
# ## <font color='#2F4F4F'>1. Defining the Question</font>

# %% [markdown]
# ### a) Specifying the Data Analysis Question
#
# Develop computer vision models that can be used to determine the age of a person from a photo

# %% [markdown]
# ### b) Defining the Metric for Success
#
# This project will be considered a success when:
# * we are able to confidently predict someone's age depending on their picture, and
# * we get at least one model with an MSE that is less than 10% of the mean of the target

# %% [markdown]
# ### c) Understanding the Context
# The Good Seed supermarket chain would like to explore whether Data Science can help them adhere to alcohol laws by making sure they do not sell alcohol to people underage. You are asked to conduct that evaluation, so as you set to work, keep the following in mind:
# * The shops are equipped with cameras in the checkout area which are triggered when a person is buying alcohol.
# * Computer vision methods can be used to determine the age of a person from a photo.
# * The task then is to build and evaluate a model for verifying people's age.

# %% [markdown]
# ### d) Recording the Experimental Design
#
# 1. Load dataset and libraries.
# 2. Clean dataset.
# 3. Carry out univariate analysis.
# 4. Carry out data modeling.
# 5. Model Evaluation
# 6. Summarize findings.
# 7. Provide recommendations.
# 8. Challenge the solution.

# %% [markdown]
# ### e) Data Relevance
#
# The data provided is sufficient and appropriate for answering the research question.

# %% [markdown]
# ## <font color='#2F4F4F'>2. Data Cleaning & Preparation</font>

# %% [markdown]
# ### 2.1 Loading necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from PIL import Image

import tensorflow as tf
from tensorflow.keras import Sequential
from keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras import regularizers, optimizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet import ResNet50
from tensorflow.keras.optimizers import Adam

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

import os, os.path

pd.set_option('display.max.columns', None)
pd.set_option('display.max_colwidth', None)
# %matplotlib inline

# %% [markdown]
# ### 2.2 Data Wrangling

# %%
# check the number of images
DIR  = 'images/'
files = os.listdir(DIR)
print(len(files))
files = sorted(files)
print(files[0],files[-1])
# Out:
# 7591
# 000000.jpg 007612.jpg

# %% [markdown]
# There are 7591 images in the folder

# %%
# load the data into our dataframe
df = pd.read_csv('labels.csv')
print(df.shape)
df
# Out:
# (7591, 2)
#        file_name  real_age
# 0     000000.jpg         4
# 1     000001.jpg        18
# 2     000002.jpg        80
# 3     000003.jpg        50
# 4     000004.jpg        17
# ...          ...       ...
# 7586  007608.jpg        14
# 7587  007609.jpg        37
# 7588  007610.jpg        28
# 7589  007611.jpg        20
# 7590  007612.jpg        47
#
# [7591 rows x 2 columns]

# %% [markdown]
# the number of images and the number of records in our labels dataframe tally, we are good to go

# %%
df.dtypes
# Out:
# file_name    object
# real_age      int64
# dtype: object

# %%
# view age statistics
df.describe()
# Out:
#           real_age
# count  7591.000000
# mean     31.201159
# std      17.145060
# min       1.000000
# 25%      20.000000
# 50%      29.000000
# 75%      41.000000
# max     100.000000

# %% [markdown]
# * youngest person is 1 year old while the oldest is 100 years old
# * The mean age of the population is 31 years

# %% [markdown]
# ### 2.3 View Sample Images

# %%
samples = df.sample(8)
samples
# Out:
#        file_name  real_age
# 1757  001757.jpg        28
# 4645  004645.jpg        40
# 992   000992.jpg        27
# 1766  001766.jpg        46
# 2064  002064.jpg         1
# 753   000753.jpg         4
# 3746  003746.jpg        68
# 1724  001724.jpg        70

# %%
samples['file_name'].values[0]
# Out:
# '001757.jpg'

# %%
# convert to an array
arr_sample = samples['file_name'].values
arr_sample
# Out:
# array(['001757.jpg', '004645.jpg', '000992.jpg', '001766.jpg',
#        '002064.jpg', '000753.jpg', '003746.jpg', '001724.jpg'],
#       dtype=object)

# %%
len(arr_sample)
# Out:
# 8

# %%
fig, ax = plt.subplots(nrows=1,ncols=len(arr_sample),figsize=(4*4,5*2))
for i in range(0,len(arr_sample)):
    fig.add_subplot(2,4, i+1)
    image = Image.open(DIR + arr_sample[i])
    im = np.array(image)
#     print(im.shape)
    plt.imshow(im)
#     remove axes    
    plt.axis('off')
    plt.grid(None)
    plt.title(str(samples['real_age'].values[i]))
    
plt.tight_layout() 
plt.show()

# %% [markdown]
# ## <font color='#2F4F4F'>3. Data Analysis</font>

# %% [markdown]
# ### 3.1 Univariate Analysis

# %%
# Distribution of the age
df.real_age.hist()
plt.show()

# %% [markdown]
# Majority of the employees are between 10-40 years of age. <br>
# The distribution is skewed slightly to the right and not completely normal/Gaussian.

# %% [markdown]
# ## <font color='#2F4F4F'>4. Data Modeling</font>

# %%
# split the dataframe into training and test datasets
train_df, test_df = train_test_split(df, test_size=0.2, random_state=1)
print(train_df.shape)
print(test_df.shape)
# Out:
# (6072, 2)
# (1519, 2)

# %%
# create our data generator for the training dataset
# split the training into 75% training and 25% validation
train_datagen=ImageDataGenerator(rescale=1./255.,validation_split=0.25)

# %%
# create a training set generator
train_generator=train_datagen.flow_from_dataframe(
    dataframe=train_df,
    directory="images/",
    x_col="file_name",
    y_col="real_age",
    subset="training",
    batch_size=32,
    seed=42,
    shuffle=True,
    class_mode="raw",
    target_size=(200,200)
)
# preview the file names
train_generator.filenames[:5]
# Out:
# Found 4554 validated image filenames.
# ['002804.jpg', '001922.jpg', '002805.jpg', '004760.jpg', '004848.jpg']

# %%
# create a validation set generator
valid_generator=train_datagen.flow_from_dataframe(
    dataframe=train_df,
    directory="images/",
    x_col="file_name",
    y_col="real_age",
    subset="validation",
    batch_size=32,
    seed=42,
    shuffle=True,
    class_mode="raw",
    target_size=(200,200)
)
# preview the file names
valid_generator.filenames[:5]
# Out:
# Found 1518 validated image filenames.
# ['004405.jpg', '006265.jpg', '005216.jpg', '005970.jpg', '001614.jpg']

# %%
# create our data generator for the test dataset
test_datagen=ImageDataGenerator(rescale=1./255.)

test_generator=test_datagen.flow_from_dataframe(
    dataframe=test_df,
    directory="images/",
    x_col="file_name",
    y_col="real_age",
    batch_size=32,
    seed=42,
    shuffle=False,
    class_mode="raw",
    target_size=(200,200)
)
# preview the file names
test_generator.filenames[:5]
# Out:
# Found 1519 validated image filenames.
# ['002563.jpg', '006066.jpg', '004395.jpg', '004320.jpg', '004072.jpg']

# %%
# build the model

# initialize the model
model = Sequential()

# first convolution layer (input layer) with 32 filters of size 3x3, and padding
# same sets the size of the padding automatically so that the width and height of the output tensor is equal 
# to the width and height of the input tensor.
model.add(Conv2D(filters=32, kernel_size=(3, 3), padding='same', input_shape=(200,200,3), activation='relu'))
# reduce the number of the model's parameters using Max Pooling with kernel size of 2x2
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add Dropout regularization functions to hidden layers in order to prevent overfitting
model.add(Dropout(0.25))

# Second convolution layer
model.add(Conv2D(filters=64, kernel_size=(3, 3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Third convolution layer
model.add(Conv2D(filters=128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# In order for the results of the convolutional layer to be compatible with a fully connected layer, connect a new layer named Flatten. 
# It makes the multidimensional tensor one-dimensional.
model.add(Flatten())

# fully connected hidden layer with 64 neurons
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

# output layer
# 'output dimension' is 1 since we are predicting one age each time.
model.add(Dense(units = 1))

# compile the model
model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = ['mean_squared_error'])

# %%
# # build the model

# # initialize the model
# model = Sequential()

# # we will use ResNet50 architecture, with freezing top layers
# backbone = ResNet50(input_shape=(256,256,3), weights='imagenet', include_top=False)
# model.add(backbone)

# # reduce the number of the model's parameters using Max Pooling with kernel
# model.add(GlobalAveragePooling2D())
# # Add Dropout regularization functions to hidden layers in order to prevent overfitting
# model.add(Dropout(0.25))



# # output layer
# # since we are doing regression we will add only one neuron (unit)
# model.add(Dense(units = 1,activation='relu'))

# # The Adam algorithm makes stride selection automatic. 
# # It selects different parameters for different neurons, which speeds up model training.
# optimizer = Adam(learning_rate=0.0003)

# model.compile(optimizer = optimizer, loss = 'mean_squared_error', metrics = ['mean_squared_error'])

# %%
train_generator.n
# Out:
# 4554

# %%
len(train_generator)
# Out:
# 143

# %%
train_generator.batch_size
# Out:
# 32

# %%
test = train_generator.n/train_generator.batch_size
test
# Out:
# 142.3125

# %%
STEP_SIZE_TRAIN=len(train_generator)
STEP_SIZE_VALID=len(valid_generator)
STEP_SIZE_TEST=len(test_generator)

# %%
# fitting the model
model.fit(train_generator,
          steps_per_epoch=STEP_SIZE_TRAIN,
          validation_data=valid_generator,
          validation_steps=STEP_SIZE_VALID,
          epochs=10
)
# Out:
# Epoch 1/10
# 143/143 [==============================] - 435s 3s/step - loss: 389.0203 - mean_squared_error: 389.0203 - val_loss: 520.7472 - val_mean_squared_error: 520.7472
# Epoch 2/10
# 143/143 [==============================] - 401s 3s/step - loss: 316.3932 - mean_squared_error: 316.3932 - val_loss: 421.0970 - val_mean_squared_error: 421.0970
# Epoch 3/10
# 143/143 [==============================] - 395s 3s/step - loss: 305.7151 - mean_squared_error: 305.7151 - val_loss: 366.1216 - val_mean_squared_error: 366.1216
# Epoch 4/10
# 143/143 [==============================] - 366s 3s/step - loss: 302.7023 - mean_squared_error: 302.7023 - val_loss: 424.7077 - val_mean_squared_error: 424.7077
# Epoch 5/10
# 143/143 [==============================] - 2311s 16s/step - loss: 301.1500 - mean_squared_error: 301.1500 - val_loss: 310.3190 - val_mean_squared_error: 310.3190
# Epoch 6/10
# 143/143 [==============================] - 339s 2s/step - loss: 291.0627 - mean_squared_error: 291.0627 - val_loss: 328.5973 - val_mean_squared_error: 328.5973
# Epoch 7/10
# 143/143 [==============================] - 546s 4s/step - loss: 276.6165 - mean_squared_error: 276.6165 - val_loss: 263.2157 - val_mean_squared_error: 263.2157
# Epoch 8/10
# 143/143 [==============================] - 577s 4s/step - loss: 276.6911 - mean_squared_error: 276.6911 - val_loss: 321.7143 - val_mean_squared_error: 321.7143
# Epoch 9/10
# 143/143 [==============================] - 685s 5s/step - loss: 263.3741 - mean_squared_error: 263.3741 - val_loss: 262.8168 - val_mean_squared_error: 262.8168
# Epoch 10/10
# 143/143 [==============================] - 518s 4s/step - loss: 258.0999 - mean_squared_error: 258.0999 - val_loss: 250.8355 - val_mean_squared_error: 250.8355

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 200, 200, 32)      896
#
#  max_pooling2d_3 (MaxPooling  (None, 100, 100, 32)     0
#  2D)
#
#  dropout_4 (Dropout)         (None, 100, 100, 32)      0
#
#  conv2d_4 (Conv2D)           (None, 100, 100, 64)      18496
#
#  max_pooling2d_4 (MaxPooling  (None, 50, 50, 64)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 50, 50, 64)        0
#
#  conv2d_5 (Conv2D)           (None, 48, 48, 128)       73856
#
#  max_pooling2d_5 (MaxPooling  (None, 24, 24, 128)      0
#  2D)
#
#  dropout_6 (Dropout)         (None, 24, 24, 128)       0
#
#  flatten_1 (Flatten)         (None, 73728)             0
#
#  dense_2 (Dense)             (None, 64)                4718656
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 4,811,969
# Trainable params: 4,811,969
# Non-trainable params: 0
# _________________________________________________________________

# %%
# evaluate the model
model.evaluate(valid_generator,steps=STEP_SIZE_TEST)
# Out:
# 48/48 [==============================] - 43s 889ms/step - loss: 250.8355 - mean_squared_error: 250.8355
# [250.83554077148438, 250.83554077148438]

# %%
# Predict the output
test_generator.reset()
predicted_ages = model.predict(test_generator,steps=STEP_SIZE_TEST,verbose=1)
# Out:
# 48/48 [==============================] - 43s 879ms/step

# %%
predicted_ages[:5]
# Out:
# array([[26.11757 ],
#        [42.78601 ],
#        [34.806835],
#        [31.588345],
#        [31.960274]], dtype=float32)

# %%
len(predicted_ages)
# Out:
# 1519

# %%
test_generator.n
# Out:
# 1519

# %% [markdown]
# ### Step 5: Model Evaluation

# %%
real_ages = test_df.iloc[:, 1:].values
real_ages[:5]
# Out:
# array([[ 7],
#        [34],
#        [ 1],
#        [59],
#        [31]], dtype=int64)

# %%
rmse = np.sqrt(mean_squared_error(real_ages, predicted_ages))
rmse
# Out:
# 16.083126208416875

# %%
# check if our RMSE is within the acceptable threshold
average = real_ages.mean()
if rmse <= real_ages.mean() * 0.1:
    print('Good Model')
else:
    print('Poor Model')
# Out:
# Poor Model

# %% [markdown]
# Our model did not perform well since the RMSE is more than 10% of the mean

# %% [markdown]
# ## <font color='#2F4F4F'>6. Summary of Findings</font>

# %% [markdown]
# The neural network was able to predict the age of a person based on their photograph generating an RMSE score of 16.

# %% [markdown]
# ## <font color='#2F4F4F'>7. Recommendations</font>

# %% [markdown]
# Upon optimizing the model to get better performance the supermarket can rely on this ANN to determine the age of their customers and ensure alcohol is not sold to underage people

# %% [markdown]
# ## <font color='#2F4F4F'>8. Challenging our Solution</font>

# %% [markdown]
# #### a) Did we have the right question?
# <i>The research question enabled us to achieve the data analysis objectives</i>
#
# #### b) Did we have the right data?
# <i>The data was relevant in addressing the set objectives</i>
#
# #### c) What can be done to improve the solution?
# <i>
# We can improve our model by:
# <li>Optimizing the epochs.</li>
# <li>Optimizing the number of layers.</li>
# <li>Optimizing the number of nodes per layer.</li>
# </i>
